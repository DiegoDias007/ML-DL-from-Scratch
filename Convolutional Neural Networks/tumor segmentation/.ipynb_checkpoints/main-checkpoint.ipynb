# %%
import tensorflow as tf
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
import numpy as np

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# ## Get the data

# %%
train_dir = "./data/train/"
val_dir = "./data/valid/"
test_dir = "./data/test/"

# %%
train_ann = train_dir + "_annotations.coco.json"
val_ann = val_dir + "_annotations.coco.json"
test_ann = test_dir + "_annotations.coco.json"

# %%
train_coco = COCO(train_ann)
val_coco = COCO(val_ann)
test_coco = COCO(test_ann)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
train_size = len(train_coco.imgs)
val_size = len(val_coco.imgs)
test_size = len(test_coco.imgs)

print("Train size:", train_size)
print("Validation size:", val_size)
print("Test size:", test_size)
# Out:
# Train size: 1502
# Validation size: 429
# Test size: 215

# %%
def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_image(image, channels=1, dtype=tf.float32)
    return image

# %%
def get_dataset(coco, size, directory, batch_size=32):
    # Get paths and annotations
    paths = [directory + coco.imgs[i]["file_name"] for i in range(size)]
    ann_ids = coco.getAnnIds()[:size]
    anns = coco.loadAnns(ann_ids)
    
    # Create masks
    masks = np.stack([coco.annToMask(ann) for ann in anns])
    masks = tf.convert_to_tensor(masks, dtype=tf.float32)
    
    # Create dataset
    path_dataset = tf.data.Dataset.from_tensor_slices(paths)
    image_dataset = path_dataset.map(read_image)
    mask_dataset = tf.data.Dataset.from_tensor_slices(masks)
    
    # Combine images and masks
    dataset = tf.data.Dataset.zip((image_dataset, mask_dataset))
    
    # Add batching and prefetching
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    return dataset

# %%
train_dataset = get_dataset(train_coco, train_size, train_dir)
val_dataset = get_dataset(val_coco, val_size, val_dir)
test_dataset = get_dataset(test_coco, test_size, test_dir)

# %%
def show_dataset_samples(dataset):
    NUMBER_SAMPLES = 3
    
    # Get a single batch from the dataset
    images, masks = next(iter(dataset))
    
    # Convert to numpy for visualization
    images = images.numpy()
    masks = masks.numpy()
    
    # Create subplots
    fig, ax = plt.subplots(NUMBER_SAMPLES, 2, figsize=(10, 10))
    
    for i in range(NUMBER_SAMPLES):
        ax1, ax2 = ax[i]
        
        ax1.imshow(images[i], cmap="gray")
        ax1.set_title(f"Image {i+1}")
        ax1.axis("off")
        
        ax2.imshow(masks[i], cmap="gray")
        ax2.set_title(f"Mask {i+1}")
        ax2.axis("off")
    
    plt.show()

# %%
show_dataset_samples(train_dataset)

# %%
def preprocess_data(images, masks):
    # Normalizing the input
    images = images / 255.0
    masks = tf.expand_dims(masks, axis=-1)
    return images, masks

# %%
train_dataset = train_dataset.map(preprocess_data)
val_dataset = val_dataset.map(preprocess_data)
test_dataset = test_dataset.map(preprocess_data)

# %% [markdown]
# ## U-Net Model

# %%
def down_block(x, n_filters, dropout_prob=0.0, want_max_pooling=True):
    """
    Convolutional downsampling block.
    
    Args:
        inputs: Input tensor.
        n_filters: Number of filters for convolutional layers.
        dropout_prob: Dropout probability.
        max_pooling: Whether to apply max pooling.

    Returns:
        next_layer: Output tensor for the next layer.
        skip_connection: Skip connection tensor.
    """
    
    out = tf.keras.layers.Conv2D(filters=n_filters, kernel_size=3, activation="relu", padding="same", kernel_initializer="he_normal")(x)
    out = tf.keras.layers.Conv2D(filters=n_filters, kernel_size=3, activation="relu", padding="same", kernel_initializer="he_normal")(out)

    if dropout_prob > 0.0:
        out = tf.keras.layers.Dropout(dropout_prob)(out)

    skip_connection = out

    if want_max_pooling:
        out = tf.keras.layers.MaxPool2D(pool_size=2)(out)

    return out, skip_connection

# %%
def up_block(x, skip_connection, n_filters):
    """
    Convolutional upsampling block.

    Args:
        expansive_input: Input tensor from previous layer.
        contractive_input: Skip connection tensor from encoding path.
        n_filters: Number of filters for convolutional layers.

    Returns:
        Output tensor after upsampling and convolution.
    """
    out = tf.keras.layers.Conv2DTranspose(filters=n_filters, kernel_size=3, strides=2, activation="relu", padding="same", kernel_initializer="he_normal")(x)

    #Concatenate skip connection
    out = tf.keras.layers.Concatenate()([out, skip_connection])

    out = tf.keras.layers.Conv2D(filters=n_filters, kernel_size=3, activation="relu", padding="same", kernel_initializer="he_normal")(out)
    out = tf.keras.layers.Conv2D(filters=n_filters, kernel_size=3, activation="relu", padding="same", kernel_initializer="he_normal")(out)
    return out

# %%
def unet_model(input_shape, n_classes, n_filters):
    """
    U-Net model implementation.

    Args:
        input_size: Shape of the input tensor.
        n_filters: Number of filters for the convolutional layers.
        n_classes: Number of output classes.

    Returns:
        U-Net model.
    """
    inputs = tf.keras.Input(shape=input_shape)

    # Down Block
    out1, skip_connection1 = down_block(inputs, n_filters)
    out2, skip_connection2 = down_block(out1, 2 * n_filters)
    out3, skip_connection3 = down_block(out2, 4 * n_filters)
    out4, skip_connection4 = down_block(out3, 8 * n_filters)
    out5, skip_connection5 = down_block(out4, 16 * n_filters, want_max_pooling=False)

    # Up Block
    up1 = up_block(out5, skip_connection4, 8 * n_filters)
    up2 = up_block(up1, skip_connection3, 4 * n_filters)
    up3 = up_block(up2, skip_connection2, 2 * n_filters)
    up4 = up_block(up3, skip_connection1, n_filters)

    outputs = tf.keras.layers.Conv2D(filters=n_classes, kernel_size=1, padding="same")(up4)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
# Getting dimensions of the input image
width = None
height = None
n_channels = None
for image, mask in train_dataset.take(1):
    _, w, h, c = image.shape
    width, height, n_channels = w, h, c

# %%
input_shape = (width, height, n_channels)

# %%
n_classes = 1
n_filters = 32
model = unet_model(input_shape, n_classes, n_filters)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 640, 640, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 640, 640, 32)      │             320 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 640, 640, 32)      │           9,248 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 320, 320, 32)      │               0 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 320, 320, 64)      │          18,496 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 320, 320, 64)      │          36,928 │ conv2d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 160, 160, 64)      │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 160, 160, 128)     │          73,856 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 160, 160, 128)     │         147,584 │ conv2d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 80, 80, 128)       │               0 │ conv2d_7[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 80, 80, 256)       │         295,168 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 80, 80, 256)       │         590,080 │ conv2d_8[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 40, 40, 256)       │               0 │ conv2d_9[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 40, 40, 512)       │       1,180,160 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 40, 40, 512)       │       2,359,808 │ conv2d_10[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 80, 80, 256)       │       1,179,904 │ conv2d_11[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 80, 80, 512)       │               0 │ conv2d_transpose[0][0],    │
# │                               │                           │                 │ conv2d_9[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 80, 80, 256)       │       1,179,904 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 80, 80, 256)       │         590,080 │ conv2d_12[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 160, 160, 128)     │         295,040 │ conv2d_13[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 160, 160, 256)     │               0 │ conv2d_transpose_1[0][0],  │
# │                               │                           │                 │ conv2d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 160, 160, 128)     │         295,040 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 160, 160, 128)     │         147,584 │ conv2d_14[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 320, 320, 64)      │          73,792 │ conv2d_15[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 320, 320, 128)     │               0 │ conv2d_transpose_2[0][0],  │
# │                               │                           │                 │ conv2d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 320, 320, 64)      │          73,792 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 320, 320, 64)      │          36,928 │ conv2d_16[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 640, 640, 32)      │          18,464 │ conv2d_17[0][0]            │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_3 (Concatenate)   │ (None, 640, 640, 64)      │               0 │ conv2d_transpose_3[0][0],  │
# │                               │                           │                 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 640, 640, 32)      │          18,464 │ concatenate_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_19 (Conv2D)            │ (None, 640, 640, 32)      │           9,248 │ conv2d_18[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_20 (Conv2D)            │ (None, 640, 640, 1)       │              33 │ conv2d_19[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 8,629,921 (32.92 MB)
#  Trainable params: 8,629,921 (32.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(1e-2)
loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)
metrics = ["accuracy"]

model.compile(
    optimizer = optimizer,
    loss = loss,
    metrics = metrics,
)

# %%
from math import ceil
train_steps = int(ceil(len(train_dataset) / BATCH_SIZE))
val_steps = int(ceil(len(val_dataset) / BATCH_SIZE))
test_steps = int(ceil(len(test_dataset) / BATCH_SIZE))

# %%
model.fit(
    train_dataset,
    epochs = 1,
    steps_per_epoch=train_steps,
    validation_data = val_dataset,
    validation_steps=val_steps
)
# Out:
# 376/376 ━━━━━━━━━━━━━━━━━━━━ 72s 187ms/step - accuracy: 0.9623 - loss: 0.1968 - val_accuracy: 0.9633 - val_loss: 0.1549

# %%
history = model.evaluate(test_dataset, steps=test_steps)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 407ms/step - accuracy: 0.9612 - loss: 0.1604

# %%
def visualize_results(images, true_masks, pred_masks, number_of_images):
    number_iterations = min(len(images), number_of_images)
    
    fig, ax = plt.subplots(number_iterations, 3, figsize=(5, number_iterations * 5))
    
    for i in range(number_iterations):
        ax[i][0].imshow(images[i], cmap="gray")
        ax[i][1].imshow(true_masks[i], cmap="gray")
        ax[i][2].imshow(pred_masks[i], cmap="gray")

        ax[i][0].set_title(f"Image {i+1}")
        ax[i][1].set_title(f"True Mask {i+1}")
        ax[i][2].set_title(f"Predicted Mask {i+1}")
    
    plt.show()

# %%
compare_results(x_test, y_test, y_pred, 5)
